# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
       (coordinate[0], coordinate[1])

# %%
from citipy import citipy

# %%
#Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 750

# %%
import requests

from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | antofagasta
# Processing Record 5 of Set 1 | samarai
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | gamboula
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | sakakah
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | asuncion
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | manicore
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | abu dhabi
# Processing Record 21 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 1 | chernolesskoye
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | camalu
# Processing Record 26 of Set 1 | saint-pierre
# Processing Record 27 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 1 | muzaffarnagar
# Processing Record 29 of Set 1 | athabasca
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | qingdao
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | maningrida
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | atchison
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | kirn
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | noumea
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | north bend
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | harper
# Processing Record 2 of Set 2 | fremont
# Processing Record 3 of Set 2 | port hardy
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | udachnyy
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | valdemarpils
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | sioux lookout
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | mnogovershinnyy
# Processing Record 16 of Set 2 | aswan
# Processing Record 17 of Set 2 | san policarpo
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | abidjan
# Processing Record 20 of Set 2 | gizo
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | shingu
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | dezful
# Processing Record 27 of Set 2 | ondjiva
# Processing Record 28 of Set 2 | sechura
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | flagstaff
# Processing Record 31 of Set 2 | kindia
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | holme
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | kavaratti
# Processing Record 39 of Set 2 | la baule-escoublac
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | waipawa
# Processing Record 44 of Set 2 | paita
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | palu
# Processing Record 47 of Set 2 | hamilton
# Processing Record 48 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 49 of Set 2 | loa janan
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | nantucket
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | olonets
# Processing Record 4 of Set 3 | pangnirtung
# Processing Record 5 of Set 3 | sarangani
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | albion
# Processing Record 8 of Set 3 | gunjur
# Processing Record 9 of Set 3 | fairbanks
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | talnakh
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | san juan
# Processing Record 14 of Set 3 | seoul
# Processing Record 15 of Set 3 | dalvik
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | muros
# Processing Record 18 of Set 3 | margate
# Processing Record 19 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 3 | tanda
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | shimoda
# Processing Record 23 of Set 3 | viedma
# Processing Record 24 of Set 3 | marawi
# Processing Record 25 of Set 3 | makakilo city
# Processing Record 26 of Set 3 | solnechnyy
# Processing Record 27 of Set 3 | poya
# Processing Record 28 of Set 3 | mitu
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | byron bay
# Processing Record 34 of Set 3 | honggang
# Processing Record 35 of Set 3 | graaff-reinet
# Processing Record 36 of Set 3 | russell
# Processing Record 37 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | tymovskoye
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | along
# Processing Record 43 of Set 3 | sibolga
# Processing Record 44 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 3 | yumen
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | kaeo
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | dumai
# Processing Record 50 of Set 3 | bijapur
# Processing Record 1 of Set 4 | labuhan
# Processing Record 2 of Set 4 | garden city
# Processing Record 3 of Set 4 | nacala
# Processing Record 4 of Set 4 | wattegama
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | namibe
# Processing Record 7 of Set 4 | salalah
# Processing Record 8 of Set 4 | karratha
# Processing Record 9 of Set 4 | hofn
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | quelimane
# Processing Record 12 of Set 4 | codrington
# Processing Record 13 of Set 4 | chingirlau
# Processing Record 14 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | qaqortoq
# Processing Record 17 of Set 4 | algiers
# Processing Record 18 of Set 4 | fagernes
# Processing Record 19 of Set 4 | avera
# Processing Record 20 of Set 4 | palafrugell
# Processing Record 21 of Set 4 | chernyshevskiy
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | venice
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | haverfordwest
# Processing Record 26 of Set 4 | mecca
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | hami
# Processing Record 30 of Set 4 | rantepao
# Processing Record 31 of Set 4 | north branch
# Processing Record 32 of Set 4 | vuktyl
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | tahta
# Processing Record 35 of Set 4 | kendari
# Processing Record 36 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 4 | kedainiai
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | griffith
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | uglegorsk
# Processing Record 42 of Set 4 | billings
# Processing Record 43 of Set 4 | karla
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | muzaffarabad
# Processing Record 46 of Set 4 | ambatolampy
# Processing Record 47 of Set 4 | butaritari
# Processing Record 48 of Set 4 | half moon bay
# Processing Record 49 of Set 4 | burnie
# Processing Record 50 of Set 4 | chkalovsk
# Processing Record 1 of Set 5 | bouna
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | bengkulu
# Processing Record 5 of Set 5 | chapais
# Processing Record 6 of Set 5 | adrar
# Processing Record 7 of Set 5 | carnarvon
# Processing Record 8 of Set 5 | cabo san lucas
# Processing Record 9 of Set 5 | verkhoyansk
# Processing Record 10 of Set 5 | bereda
# Processing Record 11 of Set 5 | balabac
# Processing Record 12 of Set 5 | shibarghan
# City not found. Skipping...
# Processing Record 13 of Set 5 | kusk
# City not found. Skipping...
# Processing Record 14 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 15 of Set 5 | aripuana
# Processing Record 16 of Set 5 | great yarmouth
# Processing Record 17 of Set 5 | vammala
# Processing Record 18 of Set 5 | sitka
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | kununurra
# Processing Record 22 of Set 5 | hong gai
# Processing Record 23 of Set 5 | kirakira
# Processing Record 24 of Set 5 | saskylakh
# Processing Record 25 of Set 5 | ucluelet
# Processing Record 26 of Set 5 | ust-tsilma
# Processing Record 27 of Set 5 | todireni
# Processing Record 28 of Set 5 | gat
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | merauke
# Processing Record 31 of Set 5 | kashi
# Processing Record 32 of Set 5 | westport
# Processing Record 33 of Set 5 | khovu-aksy
# Processing Record 34 of Set 5 | sault sainte marie
# Processing Record 35 of Set 5 | hirara
# Processing Record 36 of Set 5 | saint-augustin
# Processing Record 37 of Set 5 | nelson bay
# Processing Record 38 of Set 5 | sangmelima
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | tiznit
# Processing Record 41 of Set 5 | saint george
# Processing Record 42 of Set 5 | gondanglegi
# Processing Record 43 of Set 5 | kamyaran
# Processing Record 44 of Set 5 | dicabisagan
# Processing Record 45 of Set 5 | cutervo
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | lamu
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | saldanha
# Processing Record 1 of Set 6 | sawakin
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | kidal
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | nautla
# Processing Record 8 of Set 6 | rajo khanani
# Processing Record 9 of Set 6 | khandagayty
# Processing Record 10 of Set 6 | toamasina
# Processing Record 11 of Set 6 | nome
# Processing Record 12 of Set 6 | mount gambier
# Processing Record 13 of Set 6 | pangody
# Processing Record 14 of Set 6 | padang
# Processing Record 15 of Set 6 | solginskiy
# Processing Record 16 of Set 6 | magaria
# Processing Record 17 of Set 6 | santa cruz cabralia
# Processing Record 18 of Set 6 | cockburn town
# Processing Record 19 of Set 6 | vilhena
# Processing Record 20 of Set 6 | bairiki
# Processing Record 21 of Set 6 | sokolovyy
# Processing Record 22 of Set 6 | castro
# Processing Record 23 of Set 6 | atar
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | esperance
# Processing Record 26 of Set 6 | dunda
# Processing Record 27 of Set 6 | mikhaylovskoye
# Processing Record 28 of Set 6 | filadelfia
# Processing Record 29 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 30 of Set 6 | la palma
# Processing Record 31 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | asyut
# Processing Record 33 of Set 6 | kroya
# Processing Record 34 of Set 6 | kurkino
# Processing Record 35 of Set 6 | mantes-la-ville
# Processing Record 36 of Set 6 | marzuq
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | colesberg
# Processing Record 39 of Set 6 | ozernovskiy
# Processing Record 40 of Set 6 | lebu
# Processing Record 41 of Set 6 | azanka
# Processing Record 42 of Set 6 | mandalgovi
# Processing Record 43 of Set 6 | qom
# Processing Record 44 of Set 6 | port blair
# Processing Record 45 of Set 6 | karpogory
# Processing Record 46 of Set 6 | tevriz
# Processing Record 47 of Set 6 | tra vinh
# Processing Record 48 of Set 6 | pangai
# Processing Record 49 of Set 6 | sorland
# Processing Record 50 of Set 6 | kahului
# Processing Record 1 of Set 7 | lagoa
# Processing Record 2 of Set 7 | hobyo
# Processing Record 3 of Set 7 | baykit
# Processing Record 4 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | fare
# Processing Record 7 of Set 7 | etchojoa
# Processing Record 8 of Set 7 | flinders
# Processing Record 9 of Set 7 | tazovskiy
# Processing Record 10 of Set 7 | sawang daen din
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | muzaffarpur
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | vila velha
# Processing Record 15 of Set 7 | kathu
# Processing Record 16 of Set 7 | shizunai
# Processing Record 17 of Set 7 | azare
# Processing Record 18 of Set 7 | cortez
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | asau
# Processing Record 22 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | mokhsogollokh
# Processing Record 25 of Set 7 | sudak
# Processing Record 26 of Set 7 | wanxian
# Processing Record 27 of Set 7 | mildura
# Processing Record 28 of Set 7 | konstantinovsk
# Processing Record 29 of Set 7 | garowe
# Processing Record 30 of Set 7 | gazanjyk
# Processing Record 31 of Set 7 | mizan teferi
# Processing Record 32 of Set 7 | srednekolymsk
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | boguchany
# Processing Record 35 of Set 7 | rey bouba
# Processing Record 36 of Set 7 | bloomingdale
# Processing Record 37 of Set 7 | berlevag
# Processing Record 38 of Set 7 | laguna
# Processing Record 39 of Set 7 | praia
# Processing Record 40 of Set 7 | port alfred
# Processing Record 41 of Set 7 | zelenoborskiy
# Processing Record 42 of Set 7 | miri
# Processing Record 43 of Set 7 | otacilio costa
# Processing Record 44 of Set 7 | jijiga
# Processing Record 45 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 46 of Set 7 | zell am see
# Processing Record 47 of Set 7 | kangaatsiaq
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | voh
# Processing Record 50 of Set 7 | kataysk
# Processing Record 1 of Set 8 | roald
# Processing Record 2 of Set 8 | nemuro
# Processing Record 3 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 8 | ikovka
# Processing Record 5 of Set 8 | bathsheba
# Processing Record 6 of Set 8 | san andres
# Processing Record 7 of Set 8 | soledad
# Processing Record 8 of Set 8 | vestmanna
# Processing Record 9 of Set 8 | grand gaube
# Processing Record 10 of Set 8 | havre-saint-pierre
# Processing Record 11 of Set 8 | morganton
# Processing Record 12 of Set 8 | yerbogachen
# Processing Record 13 of Set 8 | ginda
# Processing Record 14 of Set 8 | zilupe
# Processing Record 15 of Set 8 | tibiao
# Processing Record 16 of Set 8 | yarmouth
# Processing Record 17 of Set 8 | mbuji-mayi
# Processing Record 18 of Set 8 | dwarka
# Processing Record 19 of Set 8 | pacific grove
# Processing Record 20 of Set 8 | goderich
# Processing Record 21 of Set 8 | ponta delgada
# Processing Record 22 of Set 8 | ballina
# Processing Record 23 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 8 | birnin kebbi
# Processing Record 25 of Set 8 | la ronge
# Processing Record 26 of Set 8 | langbank
# Processing Record 27 of Set 8 | morros
# Processing Record 28 of Set 8 | capreol
# Processing Record 29 of Set 8 | mutis
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | honningsvag
# Processing Record 32 of Set 8 | humboldt
# Processing Record 33 of Set 8 | kaka
# Processing Record 34 of Set 8 | nuuk
# Processing Record 35 of Set 8 | lac du bonnet
# Processing Record 36 of Set 8 | lasa
# Processing Record 37 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 8 | bolshaya dzhalga
# Processing Record 39 of Set 8 | port shepstone
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | iskitim
# Processing Record 42 of Set 8 | murska sobota
# Processing Record 43 of Set 8 | salinopolis
# Processing Record 44 of Set 8 | tambo
# Processing Record 45 of Set 8 | luganville
# Processing Record 46 of Set 8 | teeli
# Processing Record 47 of Set 8 | peddapalli
# Processing Record 48 of Set 8 | kutum
# Processing Record 49 of Set 8 | chon daen
# Processing Record 50 of Set 8 | mersing
# Processing Record 1 of Set 9 | great bend
# Processing Record 2 of Set 9 | port lincoln
# Processing Record 3 of Set 9 | ambon
# Processing Record 4 of Set 9 | sukhothai
# Processing Record 5 of Set 9 | chase
# Processing Record 6 of Set 9 | zhangye
# Processing Record 7 of Set 9 | constantine
# Processing Record 8 of Set 9 | evinayong
# Processing Record 9 of Set 9 | miguel pereira
# Processing Record 10 of Set 9 | petropavlovka
# Processing Record 11 of Set 9 | ponta do sol
# Processing Record 12 of Set 9 | weyburn
# Processing Record 13 of Set 9 | guiratinga
# Processing Record 14 of Set 9 | san borja
# Processing Record 15 of Set 9 | batagay-alyta
# Processing Record 16 of Set 9 | red bluff
# Processing Record 17 of Set 9 | sur
# Processing Record 18 of Set 9 | korla
# Processing Record 19 of Set 9 | souillac
# Processing Record 20 of Set 9 | comodoro rivadavia
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | hvide sande
# Processing Record 23 of Set 9 | wanning
# Processing Record 24 of Set 9 | nishihara
# Processing Record 25 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 9 | koudougou
# Processing Record 27 of Set 9 | krasnoselkup
# Processing Record 28 of Set 9 | yulara
# Processing Record 29 of Set 9 | sivas
# Processing Record 30 of Set 9 | gornopravdinsk
# Processing Record 31 of Set 9 | anzio
# Processing Record 32 of Set 9 | ximei
# Processing Record 33 of Set 9 | linqiong
# Processing Record 34 of Set 9 | san patricio
# Processing Record 35 of Set 9 | kilindoni
# Processing Record 36 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint-gaudens
# Processing Record 38 of Set 9 | richards bay
# Processing Record 39 of Set 9 | karsava
# Processing Record 40 of Set 9 | altar
# Processing Record 41 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | jasper
# Processing Record 43 of Set 9 | oranjestad
# Processing Record 44 of Set 9 | parrita
# Processing Record 45 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 9 | san cristobal
# Processing Record 47 of Set 9 | beloha
# Processing Record 48 of Set 9 | simnas
# Processing Record 49 of Set 9 | svetlogorsk
# Processing Record 50 of Set 9 | angoche
# Processing Record 1 of Set 10 | praia da vitoria
# Processing Record 2 of Set 10 | takoradi
# Processing Record 3 of Set 10 | guiyang
# Processing Record 4 of Set 10 | tigil
# Processing Record 5 of Set 10 | mont-dore
# Processing Record 6 of Set 10 | mosquera
# Processing Record 7 of Set 10 | imbituba
# Processing Record 8 of Set 10 | union
# Processing Record 9 of Set 10 | natal
# Processing Record 10 of Set 10 | komsomolskiy
# Processing Record 11 of Set 10 | vostok
# Processing Record 12 of Set 10 | ahipara
# Processing Record 13 of Set 10 | khilok
# Processing Record 14 of Set 10 | iqaluit
# Processing Record 15 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 10 | vadinsk
# Processing Record 17 of Set 10 | ingham
# Processing Record 18 of Set 10 | katsuura
# Processing Record 19 of Set 10 | saint-fabien
# City not found. Skipping...
# Processing Record 20 of Set 10 | marsh harbour
# Processing Record 21 of Set 10 | tiksi
# Processing Record 22 of Set 10 | roccastrada
# Processing Record 23 of Set 10 | porto seguro
# Processing Record 24 of Set 10 | zholymbet
# Processing Record 25 of Set 10 | tabuk
# Processing Record 26 of Set 10 | balkhash
# Processing Record 27 of Set 10 | terre-de-bas
# Processing Record 28 of Set 10 | boende
# Processing Record 29 of Set 10 | inuvik
# Processing Record 30 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 10 | buala
# Processing Record 32 of Set 10 | leningradskiy
# Processing Record 33 of Set 10 | bilibino
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | ishigaki
# Processing Record 36 of Set 10 | taoudenni
# Processing Record 37 of Set 10 | turukhansk
# Processing Record 38 of Set 10 | los llanos de aridane
# Processing Record 39 of Set 10 | prado
# Processing Record 40 of Set 10 | egvekinot
# Processing Record 41 of Set 10 | marsabit
# Processing Record 42 of Set 10 | nalut
# Processing Record 43 of Set 10 | dhadar
# Processing Record 44 of Set 10 | port hedland
# Processing Record 45 of Set 10 | brae
# Processing Record 46 of Set 10 | atambua
# Processing Record 47 of Set 10 | erenhot
# Processing Record 48 of Set 10 | hanmer springs
# Processing Record 49 of Set 10 | kondopoga
# Processing Record 50 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 11 | yagodnoye
# Processing Record 2 of Set 11 | lagunillas
# Processing Record 3 of Set 11 | kautokeino
# Processing Record 4 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 11 | angoram
# Processing Record 6 of Set 11 | xuddur
# Processing Record 7 of Set 11 | bure
# Processing Record 8 of Set 11 | narsaq
# Processing Record 9 of Set 11 | nouadhibou
# Processing Record 10 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 11 | tanjong karang
# City not found. Skipping...
# Processing Record 12 of Set 11 | marystown
# Processing Record 13 of Set 11 | soyo
# Processing Record 14 of Set 11 | tengzhou
# Processing Record 15 of Set 11 | nisia floresta
# Processing Record 16 of Set 11 | haines junction
# Processing Record 17 of Set 11 | les cayes
# Processing Record 18 of Set 11 | vero beach
# Processing Record 19 of Set 11 | matagami
# Processing Record 20 of Set 11 | touros
# Processing Record 21 of Set 11 | dhidhdhoo
# Processing Record 22 of Set 11 | lulea
# Processing Record 23 of Set 11 | forestville
# Processing Record 24 of Set 11 | baruun-urt
# Processing Record 25 of Set 11 | foumban
# Processing Record 26 of Set 11 | kismayo
# Processing Record 27 of Set 11 | wiang sa
# Processing Record 28 of Set 11 | saint-joseph
# Processing Record 29 of Set 11 | sembabule
# Processing Record 30 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 11 | alta floresta
# Processing Record 32 of Set 11 | daru
# Processing Record 33 of Set 11 | lompoc
# Processing Record 34 of Set 11 | evensk
# Processing Record 35 of Set 11 | stoughton
# Processing Record 36 of Set 11 | necochea
# Processing Record 37 of Set 11 | wakkanai
# Processing Record 38 of Set 11 | batticaloa
# Processing Record 39 of Set 11 | angelokhorion
# City not found. Skipping...
# Processing Record 40 of Set 11 | isangel
# Processing Record 41 of Set 11 | maracacume
# Processing Record 42 of Set 11 | kjollefjord
# Processing Record 43 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 44 of Set 11 | nizhniy odes
# Processing Record 45 of Set 11 | okhotsk
# Processing Record 46 of Set 11 | oranjemund
# Processing Record 47 of Set 11 | matadi
# Processing Record 48 of Set 11 | acari
# Processing Record 49 of Set 11 | zenzeli
# Processing Record 50 of Set 11 | panaba
# Processing Record 1 of Set 12 | port pirie
# Processing Record 2 of Set 12 | palauig
# Processing Record 3 of Set 12 | kaniama
# Processing Record 4 of Set 12 | novyy svit
# Processing Record 5 of Set 12 | grindavik
# Processing Record 6 of Set 12 | pathein
# Processing Record 7 of Set 12 | broome
# Processing Record 8 of Set 12 | leova
# Processing Record 9 of Set 12 | astana
# Processing Record 10 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 11 of Set 12 | nykobing
# City not found. Skipping...
# Processing Record 12 of Set 12 | tezu
# Processing Record 13 of Set 12 | rocha
# Processing Record 14 of Set 12 | karaton
# Processing Record 15 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 12 | wuning
# Processing Record 17 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 18 of Set 12 | nong ki
# Processing Record 19 of Set 12 | namtsy
# Processing Record 20 of Set 12 | keuruu
# Processing Record 21 of Set 12 | kurmanayevka
# Processing Record 22 of Set 12 | grabovo
# Processing Record 23 of Set 12 | fairlie
# Processing Record 24 of Set 12 | arica
# Processing Record 25 of Set 12 | tutoia
# Processing Record 26 of Set 12 | plavsk
# Processing Record 27 of Set 12 | morondava
# Processing Record 28 of Set 12 | itarema
# Processing Record 29 of Set 12 | kanashevo
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | urbana
# Processing Record 32 of Set 12 | heihe
# Processing Record 33 of Set 12 | mahon
# Processing Record 34 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 12 | kaihua
# Processing Record 36 of Set 12 | havoysund
# Processing Record 37 of Set 12 | vermilion
# Processing Record 38 of Set 12 | kibala
# Processing Record 39 of Set 12 | aguimes
# Processing Record 40 of Set 12 | faya
# Processing Record 41 of Set 12 | flin flon
# Processing Record 42 of Set 12 | shitanjing
# Processing Record 43 of Set 12 | hanyang
# Processing Record 44 of Set 12 | maldonado
# Processing Record 45 of Set 12 | plettenberg bay
# Processing Record 46 of Set 12 | husavik
# Processing Record 47 of Set 12 | altay
# Processing Record 48 of Set 12 | triunfo
# Processing Record 49 of Set 12 | rabo de peixe
# Processing Record 50 of Set 12 | xinyu
# Processing Record 1 of Set 13 | vestmannaeyjar
# Processing Record 2 of Set 13 | hurghada
# Processing Record 3 of Set 13 | ewa beach
# Processing Record 4 of Set 13 | deputatskiy
# Processing Record 5 of Set 13 | urusha
# Processing Record 6 of Set 13 | baker city
# Processing Record 7 of Set 13 | minas de barroteran
# Processing Record 8 of Set 13 | bhindar
# Processing Record 9 of Set 13 | igdir
# Processing Record 10 of Set 13 | san quintin
# Processing Record 11 of Set 13 | chumikan
# Processing Record 12 of Set 13 | ust-kuyga
# Processing Record 13 of Set 13 | carballo
# Processing Record 14 of Set 13 | palana
# Processing Record 15 of Set 13 | mizpe ramon
# City not found. Skipping...
# Processing Record 16 of Set 13 | san francisco del mar
# Processing Record 17 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 13 | guekedou
# City not found. Skipping...
# Processing Record 19 of Set 13 | buraydah
# Processing Record 20 of Set 13 | turtas
# Processing Record 21 of Set 13 | mackenzie
# Processing Record 22 of Set 13 | agva
# City not found. Skipping...
# Processing Record 23 of Set 13 | camapua
# Processing Record 24 of Set 13 | liuzhou
# Processing Record 25 of Set 13 | ous
# Processing Record 26 of Set 13 | varzea grande
# Processing Record 27 of Set 13 | urumqi
# Processing Record 28 of Set 13 | partizanskoye
# Processing Record 29 of Set 13 | zhuanghe
# Processing Record 30 of Set 13 | bend
# Processing Record 31 of Set 13 | xichang
# Processing Record 32 of Set 13 | ust-nera
# Processing Record 33 of Set 13 | kushima
# Processing Record 34 of Set 13 | ginir
# Processing Record 35 of Set 13 | arlit
# Processing Record 36 of Set 13 | tura
# Processing Record 37 of Set 13 | gornyy
# Processing Record 38 of Set 13 | cururupu
# Processing Record 39 of Set 13 | bonavista
# Processing Record 40 of Set 13 | andenes
# Processing Record 41 of Set 13 | vilyuysk
# Processing Record 42 of Set 13 | artyom
# Processing Record 43 of Set 13 | fayaoue
# Processing Record 44 of Set 13 | neiafu
# Processing Record 45 of Set 13 | apatou
# Processing Record 46 of Set 13 | sumenep
# Processing Record 47 of Set 13 | minna
# Processing Record 48 of Set 13 | mandera
# Processing Record 49 of Set 13 | ferkessedougou
# Processing Record 50 of Set 13 | santa cruz
# Processing Record 1 of Set 14 | katha
# City not found. Skipping...
# Processing Record 2 of Set 14 | ambulu
# Processing Record 3 of Set 14 | olkhovka
# Processing Record 4 of Set 14 | ankazobe
# Processing Record 5 of Set 14 | lodeynoye pole
# Processing Record 6 of Set 14 | vieux-habitants
# Processing Record 7 of Set 14 | tancheng
# Processing Record 8 of Set 14 | kargasok
# Processing Record 9 of Set 14 | ambunti
# Processing Record 10 of Set 14 | olafsvik
# Processing Record 11 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 14 | anaconda
# Processing Record 13 of Set 14 | sungaipenuh
# Processing Record 14 of Set 14 | rio gallegos
# Processing Record 15 of Set 14 | borogontsy
# Processing Record 16 of Set 14 | bulawayo
# Processing Record 17 of Set 14 | muana
# Processing Record 18 of Set 14 | luanda
# Processing Record 19 of Set 14 | victor harbor
# Processing Record 20 of Set 14 | uspenka
# Processing Record 21 of Set 14 | bandar-e lengeh
# Processing Record 22 of Set 14 | college
# Processing Record 23 of Set 14 | seymchan
# Processing Record 24 of Set 14 | chicama
# Processing Record 25 of Set 14 | chastoozerye
# City not found. Skipping...
# Processing Record 26 of Set 14 | jurm
# Processing Record 27 of Set 14 | almere
# Processing Record 28 of Set 14 | khorixas
# Processing Record 29 of Set 14 | coihueco
# Processing Record 30 of Set 14 | sabang
# Processing Record 31 of Set 14 | rosarito
# Processing Record 32 of Set 14 | waddan
# Processing Record 33 of Set 14 | sola
# Processing Record 34 of Set 14 | borova
# Processing Record 35 of Set 14 | makow mazowiecki
# Processing Record 36 of Set 14 | yar-sale
# Processing Record 37 of Set 14 | beyneu
# Processing Record 38 of Set 14 | vao
# Processing Record 39 of Set 14 | worland
# Processing Record 40 of Set 14 | camacari
# Processing Record 41 of Set 14 | morden
# Processing Record 42 of Set 14 | serro
# Processing Record 43 of Set 14 | luba
# Processing Record 44 of Set 14 | saint pete beach
# Processing Record 45 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 46 of Set 14 | mantua
# Processing Record 47 of Set 14 | kloulklubed
# Processing Record 48 of Set 14 | polson
# Processing Record 49 of Set 14 | coihaique
# Processing Record 50 of Set 14 | naze
# Processing Record 1 of Set 15 | kiama
# Processing Record 2 of Set 15 | teguldet
# Processing Record 3 of Set 15 | rosario
# Processing Record 4 of Set 15 | kon tum
# Processing Record 5 of Set 15 | enugu
# Processing Record 6 of Set 15 | tautira
# Processing Record 7 of Set 15 | fort nelson
# Processing Record 8 of Set 15 | zhireken
# Processing Record 9 of Set 15 | nesterovskaya
# Processing Record 10 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 15 | choya
# Processing Record 12 of Set 15 | ankpa
# Processing Record 13 of Set 15 | bousso
# Processing Record 14 of Set 15 | ambilobe
# Processing Record 15 of Set 15 | sungairaya
# Processing Record 16 of Set 15 | tilichiki
# Processing Record 17 of Set 15 | camacha
# Processing Record 18 of Set 15 | broken hill
# Processing Record 19 of Set 15 | ossora
# Processing Record 20 of Set 15 | baghdad
# Processing Record 21 of Set 15 | manta
# Processing Record 22 of Set 15 | bilma
# Processing Record 23 of Set 15 | lukaya
# Processing Record 24 of Set 15 | porbandar
# Processing Record 25 of Set 15 | cedar city
# Processing Record 26 of Set 15 | hammerfest
# Processing Record 27 of Set 15 | chala
# Processing Record 28 of Set 15 | hailar
# Processing Record 29 of Set 15 | inirida
# Processing Record 30 of Set 15 | boda
# Processing Record 31 of Set 15 | kuloy
# Processing Record 32 of Set 15 | buchanan
# Processing Record 33 of Set 15 | bukachacha
# Processing Record 34 of Set 15 | koshurnikovo
# Processing Record 35 of Set 15 | acajutla
# Processing Record 36 of Set 15 | mirnyy
# Processing Record 37 of Set 15 | kerrville
# Processing Record 38 of Set 15 | mangrol
# Processing Record 39 of Set 15 | obidos
# Processing Record 40 of Set 15 | eyl
# Processing Record 41 of Set 15 | curitiba
# Processing Record 42 of Set 15 | catamarca
# Processing Record 43 of Set 15 | yatou
# Processing Record 44 of Set 15 | comarapa
# Processing Record 45 of Set 15 | isla vista
# Processing Record 46 of Set 15 | ushibuka
# Processing Record 47 of Set 15 | oskarshamn
# Processing Record 48 of Set 15 | namie
# Processing Record 49 of Set 15 | boddam
# Processing Record 50 of Set 15 | cootamundra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df_2 = pd.DataFrame(city_data)
city_data_df_2.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     46.47        70          76
# 1    Georgetown   5.4112  100.3354     78.73        93          40
# 2       Ushuaia -54.8000  -68.3000     47.86        40           0
# 3   Antofagasta -23.6500  -70.4000     56.48        77          17
# 4       Samarai -10.6167  150.6667     82.18        77          22
# 5  Punta Arenas -53.1500  -70.9167     39.31        70           0
# 6   New Norfolk -42.7826  147.0587     58.50        58         100
# 7       Aklavik  68.2191 -135.0107     41.59        84         100
# 8       Rikitea -23.1203 -134.9692     70.63        73           9
# 9        Atuona  -9.8000 -139.0333     76.53        75          17
#
#    Wind Speed Country                 Date
# 0       12.93      NZ  2022-09-15 04:58:56
# 1        8.05      MY  2022-09-15 04:54:56
# 2       12.66      AR  2022-09-15 04:56:47
# 3        2.71      CL  2022-09-15 04:54:23
# 4       11.12      PG  2022-09-15 04:58:56
# 5       16.11      CL  2022-09-15 04:54:41
# 6        1.01      AU  2022-09-15 04:58:57
# 7        3.56      CA  2022-09-15 04:58:57
# 8       13.22      PF  2022-09-15 04:58:57
# 9       17.85      PF  2022-09-15 04:58:58

# %%
new_column_order = ["City", "Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df_2.to_csv(output_data_file, index_label="City_ID")
